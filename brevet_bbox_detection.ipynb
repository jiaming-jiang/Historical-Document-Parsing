# %% [markdown]
# # 📄 Brevet Detection with Bounding Boxes

# %%
import os
import pytesseract
from PIL import Image
import pandas as pd
from fuzzywuzzy import fuzz


pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# ## 🔍 OCR Extraction with Bounding Boxes

# %%
def extract_ocr_data(image_path):
    """Run Tesseract OCR and return DataFrame with bounding boxes."""
    image = Image.open(image_path)
    df = pytesseract.image_to_data(image, output_type=pytesseract.Output.DATAFRAME)
    
    # Ensure text column is string before using .str
    df["text"] = df["text"].astype(str)
    df = df[df.text.notnull() & (df.text.str.strip() != "")]
    
    return df.reset_index(drop=True)

# %% [markdown]
# ## 🤖 Fuzzy Matching + Location-Based Detection

# %%
def is_fuzzy_match(word, target, threshold=70):
    """Check if OCR word is a fuzzy match to the target string."""
    return fuzz.ratio(word.upper(), target.upper()) >= threshold

def detect_brevet_blocks_with_bbox(ocr_df, x_range=(600, 1000), y_range=(500, 600), min_words=3):
    """
    Detect probable BREVET blocks using bounding boxes and fuzzy matching.
    Returns a list of dicts with matched block info.
    """
    matches = []
    for idx, row in ocr_df.iterrows():
        if (x_range[0] <= row.left <= x_range[1]) and (y_range[0] <= row.top <= y_range[1]):
            if is_fuzzy_match(row.text, "BREVET"):
                nearby = ocr_df[
                    (ocr_df.page_num == row.page_num) &
                    (abs(ocr_df.top - row.top) < 50) &
                    (abs(ocr_df.left - row.left) < 300)
                ]
                block_text = " ".join(nearby.sort_values(by="left").text.tolist())
                if len(block_text.split()) >= min_words:
                    matches.append({
                        "page": row.page_num,
                        "top": row.top,
                        "left": row.left,
                        "block_text": block_text
                    })
    return matches

# %% [markdown]
# ## 📁 Process All Page Images in a Folder

# %%
def process_images_in_folder(folder_path):
    """Process all image files in a folder and detect BREVET blocks."""
    results = []
    for file in sorted(os.listdir(folder_path)):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            path = os.path.join(folder_path, file)
            print(f"Processing {file}...")
            ocr_df = extract_ocr_data(path)
            blocks = detect_brevet_blocks_with_bbox(ocr_df)
            for b in blocks:
                b["image_file"] = file
                results.append(b)
    return pd.DataFrame(results)

# %% [markdown]
# ## 🚀 Run It

# %%
# Example usage:
# Make sure your images are in a folder like 'output_12/'
df = process_images_in_folder('BW_12')
display(df.head())
# Out:
# Processing page_001.png...
# Processing page_002.png...
# Processing page_003.png...
# Processing page_004.png...
# Processing page_005.png...
# Processing page_006.png...
# Processing page_007.png...
# Processing page_008.png...
# Processing page_009.png...
# Processing page_010.png...
# Processing page_011.png...
# Processing page_012.png...
# Processing page_013.png...
# Processing page_014.png...
# Processing page_015.png...
# Processing page_016.png...
# Processing page_017.png...
# Processing page_018.png...
# Processing page_019.png...
# Processing page_020.png...
# Processing page_021.png...
# Processing page_022.png...
# Processing page_023.png...
# Processing page_024.png...
# Processing page_025.png...
# Processing page_026.png...
# Processing page_027.png...
# Processing page_028.png...
# Processing page_029.png...
# Processing page_030.png...
# Processing page_031.png...
# Processing page_032.png...
# Processing page_033.png...
# Processing page_034.png...
# Processing page_035.png...
# Processing page_036.png...
# Processing page_037.png...
# Processing page_038.png...
# Processing page_039.png...
# Processing page_040.png...
# Processing page_041.png...
# Processing page_042.png...
# Processing page_043.png...
# Processing page_044.png...
# Processing page_045.png...
# Processing page_046.png...
# Processing page_047.png...
# Processing page_048.png...
# Processing page_049.png...
# Processing page_050.png...
# Processing page_051.png...
# Processing page_052.png...
# Processing page_053.png...
# Processing page_054.png...
# Processing page_055.png...
# Processing page_056.png...
# Processing page_057.png...
# Processing page_058.png...
# Processing page_059.png...
# Processing page_060.png...
# Processing page_061.png...
# Processing page_062.png...
# Processing page_063.png...
# Processing page_064.png...
# Processing page_065.png...
# Processing page_066.png...
# Processing page_067.png...
# Processing page_068.png...
# Processing page_069.png...
# Processing page_070.png...
# Processing page_071.png...
# Processing page_072.png...
# Processing page_073.png...
# Processing page_074.png...
# Processing page_075.png...
# Processing page_076.png...
# Processing page_077.png...
# Processing page_078.png...
# Processing page_079.png...
# Processing page_080.png...
# Processing page_081.png...
# Processing page_082.png...
# Processing page_083.png...
# Processing page_084.png...
# Processing page_085.png...
# Processing page_086.png...
# Processing page_087.png...
# Processing page_088.png...
# Processing page_089.png...
# Processing page_090.png...
# Processing page_091.png...
# Processing page_092.png...
# Processing page_093.png...
# Processing page_094.png...
# Processing page_095.png...
# Processing page_096.png...
# Processing page_097.png...
# Processing page_098.png...
# Processing page_099.png...
# Processing page_100.png...
# Processing page_101.png...
# Processing page_102.png...
# Processing page_103.png...
# Processing page_104.png...
# Processing page_105.png...
# Processing page_106.png...
# Processing page_107.png...
# Processing page_108.png...
# Processing page_109.png...
# Processing page_110.png...
# Processing page_111.png...
# Processing page_112.png...
# Processing page_113.png...
# Processing page_114.png...
# Processing page_115.png...
# Processing page_116.png...
# Processing page_117.png...
# Processing page_118.png...
# Processing page_119.png...
# Processing page_120.png...
# Processing page_121.png...
# Processing page_122.png...
# Processing page_123.png...
# Processing page_124.png...
# Processing page_125.png...
# Processing page_126.png...
# Processing page_127.png...
# Processing page_128.png...
# Processing page_129.png...
# Processing page_130.png...
# Processing page_131.png...
# Processing page_132.png...
# Processing page_133.png...
# Processing page_134.png...
# Processing page_135.png...
# Processing page_136.png...
# Processing page_137.png...
# Processing page_138.png...
# Processing page_139.png...
# Processing page_140.png...
# Processing page_141.png...
# Processing page_142.png...
# Processing page_143.png...
# Processing page_144.png...
# Processing page_145.png...
# Processing page_146.png...
# Processing page_147.png...
# Processing page_148.png...
# Processing page_149.png...
# Processing page_150.png...
# Processing page_151.png...
# Processing page_152.png...
# Processing page_153.png...
# Processing page_154.png...
# Processing page_155.png...
# Processing page_156.png...
# Processing page_157.png...
# Processing page_158.png...
# Processing page_159.png...
# Processing page_160.png...
# Processing page_161.png...
# Processing page_162.png...
# Processing page_163.png...
# Processing page_164.png...
# Processing page_165.png...
# Processing page_166.png...
# Processing page_167.png...
# Processing page_168.png...
# Processing page_169.png...
# Processing page_170.png...
# Processing page_171.png...
# Processing page_172.png...
# Processing page_173.png...
# Processing page_174.png...
# Processing page_175.png...
# Processing page_176.png...
# Processing page_177.png...
# Processing page_178.png...
# Processing page_179.png...
# Processing page_180.png...
# Processing page_181.png...
# Processing page_182.png...
# Processing page_183.png...
# Processing page_184.png...
# Processing page_185.png...
# Processing page_186.png...
# Processing page_187.png...
# Processing page_188.png...
# Processing page_189.png...
# Processing page_190.png...
# Processing page_191.png...
# Processing page_192.png...
# Processing page_193.png...
# Processing page_194.png...
# Processing page_195.png...
# Processing page_196.png...
# Processing page_197.png...
# Processing page_198.png...
# Processing page_199.png...
# Processing page_200.png...
# Processing page_201.png...
# Processing page_202.png...
# Processing page_203.png...
# Processing page_204.png...
# Processing page_205.png...
# Processing page_206.png...
# Processing page_207.png...
# Processing page_208.png...
# Processing page_209.png...
# Processing page_210.png...
# Processing page_211.png...
# Processing page_212.png...
# Processing page_213.png...
# Processing page_214.png...
# Processing page_215.png...
# Processing page_216.png...
# Processing page_217.png...
# Processing page_218.png...
# Processing page_219.png...
# Processing page_220.png...
# Processing page_221.png...
# Processing page_222.png...
# Processing page_223.png...
# Processing page_224.png...
# Processing page_225.png...
# Processing page_226.png...
# Processing page_227.png...
# Processing page_228.png...
# Processing page_229.png...
# Processing page_230.png...
# Processing page_231.png...
# Processing page_232.png...
# Processing page_233.png...
# Processing page_234.png...
# Processing page_235.png...
# Processing page_236.png...
# Processing page_237.png...
# Processing page_238.png...
# Processing page_239.png...
# Processing page_240.png...
# Processing page_241.png...
# Processing page_242.png...
# Processing page_243.png...
# Processing page_244.png...
# Processing page_245.png...
# Processing page_246.png...
# Processing page_247.png...
# Processing page_248.png...
# Processing page_249.png...
# Processing page_250.png...
# Processing page_251.png...
# Processing page_252.png...
# Processing page_253.png...
# Processing page_254.png...
# Processing page_255.png...
# Processing page_256.png...
# Processing page_257.png...
# Processing page_258.png...
# Processing page_259.png...
# Processing page_260.png...
# Processing page_261.png...
# Processing page_262.png...
# Processing page_263.png...
# Processing page_264.png...
# Processing page_265.png...
# Processing page_266.png...
# Processing page_267.png...
# Processing page_268.png...
# Processing page_269.png...
# Processing page_270.png...
# Processing page_271.png...
# Processing page_272.png...
# Processing page_273.png...
# Processing page_274.png...
# Processing page_275.png...
# Processing page_276.png...
# Processing page_277.png...
# Processing page_278.png...
# Processing page_279.png...
# Processing page_280.png...
# Processing page_281.png...
# Processing page_282.png...
# Processing page_283.png...
# Processing page_284.png...
# Processing page_285.png...
# Processing page_286.png...
# Processing page_287.png...
# Processing page_288.png...
# Processing page_289.png...
# Processing page_290.png...
# Processing page_291.png...
# Processing page_292.png...
# Processing page_293.png...
# Processing page_294.png...
# Processing page_295.png...
# Processing page_296.png...
# Processing page_297.png...
# Processing page_298.png...
# Processing page_299.png...
# Processing page_300.png...
# Processing page_301.png...
# Processing page_302.png...
# Processing page_303.png...
# Processing page_304.png...
# Processing page_305.png...
# Processing page_306.png...
# Processing page_307.png...
# Processing page_308.png...
# Processing page_309.png...
# Processing page_310.png...
# Processing page_311.png...
# Processing page_312.png...
# Processing page_313.png...
# Processing page_314.png...
# Processing page_315.png...
# Processing page_316.png...
# Processing page_317.png...
# Processing page_318.png...
# Processing page_319.png...
# Processing page_320.png...
# Processing page_321.png...
# Processing page_322.png...
# Processing page_323.png...
# Processing page_324.png...
# Processing page_325.png...
# Processing page_326.png...
# Processing page_327.png...
# Processing page_328.png...
# Processing page_329.png...
# Processing page_330.png...
# Processing page_331.png...
# Processing page_332.png...
# Processing page_333.png...
# Processing page_334.png...
# Processing page_335.png...
# Processing page_336.png...
# Processing page_337.png...
# Processing page_338.png...
# Processing page_339.png...
# Processing page_340.png...
# Processing page_341.png...
# Processing page_342.png...
# Processing page_343.png...
# Processing page_344.png...
# Processing page_345.png...
# Processing page_346.png...
# Processing page_347.png...
# Processing page_348.png...
# Processing page_349.png...
# Processing page_350.png...
# Processing page_351.png...
# Processing page_352.png...
# Processing page_353.png...
# Processing page_354.png...
# Processing page_355.png...
# Processing page_356.png...
# Processing page_357.png...
# Processing page_358.png...
# Processing page_359.png...
# Processing page_360.png...
# Processing page_361.png...
# Processing page_362.png...
# Processing page_363.png...
# Processing page_364.png...
# Processing page_365.png...
# Processing page_366.png...
# Processing page_367.png...
# Processing page_368.png...
# Processing page_369.png...
# Processing page_370.png...
# Processing page_371.png...
# Processing page_372.png...
# Processing page_373.png...
# Processing page_374.png...
# Processing page_375.png...
# Processing page_376.png...
# Processing page_377.png...
# Processing page_378.png...
# Processing page_379.png...
# Processing page_380.png...
# Processing page_381.png...
# Processing page_382.png...
# Processing page_383.png...
# Processing page_384.png...
# Processing page_385.png...
# Processing page_386.png...
# Processing page_387.png...
# Processing page_388.png...
# Processing page_389.png...
# Processing page_390.png...
# Processing page_391.png...
# Processing page_392.png...
# Processing page_393.png...
# Processing page_394.png...
# Processing page_395.png...
# Processing page_396.png...
# Processing page_397.png...
# Processing page_398.png...
# Processing page_399.png...
# Processing page_400.png...
# Processing page_401.png...
# Processing page_402.png...
# Processing page_403.png...
# Processing page_404.png...
# Processing page_405.png...
# Processing page_406.png...
# Processing page_407.png...
# Processing page_408.png...
# Processing page_409.png...
# Processing page_410.png...
# Processing page_411.png...
# Processing page_412.png...
# Processing page_413.png...
# Processing page_414.png...
# Processing page_415.png...
# Processing page_416.png...
# Processing page_417.png...
# Processing page_418.png...
# Processing page_419.png...
# Processing page_420.png...
# Processing page_421.png...
# Processing page_422.png...
# Processing page_423.png...
# Processing page_424.png...
# Processing page_425.png...
# Processing page_426.png...
# Processing page_427.png...
# Processing page_428.png...
# Processing page_429.png...
# Processing page_430.png...
# Processing page_431.png...
# Processing page_432.png...
# Processing page_433.png...
# Processing page_434.png...
# Processing page_435.png...
# Processing page_436.png...
# Processing page_437.png...
# Processing page_438.png...
# Processing page_439.png...
# Processing page_440.png...
# Processing page_441.png...
# Processing page_442.png...
# Processing page_443.png...
# Processing page_444.png...
# Processing page_445.png...
# Processing page_446.png...
# Processing page_447.png...
# Processing page_448.png...
# Processing page_449.png...
# Processing page_450.png...
# Processing page_451.png...
# Processing page_452.png...
# Processing page_453.png...
# Processing page_454.png...
# Processing page_455.png...
# Processing page_456.png...
# Processing page_457.png...
# Processing page_458.png...
# Processing page_459.png...
# Processing page_460.png...
# Processing page_461.png...
# Processing page_462.png...
# Processing page_463.png...
# Processing page_464.png...
# Processing page_465.png...
# Processing page_466.png...
# Processing page_467.png...
# Processing page_468.png...
# Processing page_469.png...
# Processing page_470.png...
# Processing page_471.png...
# Processing page_472.png...
# Processing page_473.png...
# Processing page_474.png...
# Processing page_475.png...
# Processing page_476.png...
# Processing page_477.png...
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(df)
# Out:
# 0
